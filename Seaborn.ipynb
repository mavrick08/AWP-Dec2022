# %% [markdown]
# pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
help(sns.load_dataset)
# Out:
# Help on function load_dataset in module seaborn.utils:
#
# load_dataset(name, cache=True, data_home=None, **kws)
#     Load an example dataset from the online repository (requires internet).
#
#     This function provides quick access to a small number of example datasets
#     that are useful for documenting seaborn or generating reproducible examples
#     for bug reports. It is not necessary for normal usage.
#
#     Note that some of the datasets have a small amount of preprocessing applied
#     to define a proper ordering for categorical variables.
#
#     Use :func:`get_dataset_names` to see a list of available datasets.
#
#     Parameters
#     ----------
#     name : str
#         Name of the dataset (``{name}.csv`` on
#         https://github.com/mwaskom/seaborn-data).
#     cache : boolean, optional
#         If True, try to load from the local cache first, and save to the cache
#         if a download is required.
#     data_home : string, optional
# ...

# %%
tips_data = sns.load_dataset('tips')

# %%
tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style(style='whitegrid')

# %%
sns.lineplot(x='size',y='total_bill',data=tips_data)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.scatterplot(x='size',y='total_bill',data=tips_data)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips_data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=tips_data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',hue='smoker',data=tips_data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',hue='time',data=tips_data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
my_marker = {'Male':"P",'Female':"X"}
colors = ['#FF0000','#89CFF0']
sns.set_palette(sns.color_palette(colors))
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=tips_data,style='sex',markers=my_marker,legend=False)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips_data['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
data = sns.load_dataset('flights')

# %%
data
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.relplot(data,x='month',y='passengers',kind='line',ci=None)
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',data=tips_data,col='time')

# %%
tips_data['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.displot(titanic['age'])

# %%
sns.displot(titanic['age'],kde=True)

# %%
sns.displot(titanic['age'],bins=20)

# %%
sns.displot(titanic,x='age',hue='pclass')

# %%
sns.displot(titanic,x='age',hue='sex',palette='rocket')

# %%
titanic['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
sns.histplot(titanic,x='age',hue='survived',palette='rocket')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(data=tips_data,x='tip',hue='day')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.catplot(data=titanic,x='sex',y='survived',hue='class',kind='bar')

# %%
sns.barplot(data=tips_data,x='sex',y='total_bill',hue='day')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(data=tips_data,x='day')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.boxplot(data=tips_data,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips_data,x='day',y='total_bill',hue='smoker',kind='box')

# %%
sns.swarmplot(data=tips_data,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.lmplot(data=tips_data,x='total_bill',y='tip')

# %%
sns.boxenplot(data=tips_data,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.pairplot(tips_data)

# %%
sns.pairplot(titanic)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.set()
graph = sns.catplot(data=tips_data,x='day',y='total_bill',hue='smoker',kind='box')
graph.set_xticklabels(rotation=60)

# %%
+
